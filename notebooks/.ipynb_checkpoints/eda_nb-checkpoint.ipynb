# %%
import pandas as pd

# %%
filepath = "../data/dec19pub.csv"
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#             HRHHID  HRMONTH  HRYEAR4  HURESPLI  HUFINAL  HULANGCODE  HETENURE  \
# 0  581125017600866       12     2019         2      201           0         1
# 1  581125017600866       12     2019         2      201           0         1
# 2  581125017600866       12     2019         2      201           0         1
# 3  581125017600866       12     2019         2      201           0         1
# 4  809001585510960       12     2019         1      201           0         2
#
#    HEHOUSUT  HETELHHD  HETELAVL  ...  HRFS30D1  HRFS30D2  HRFS30D3  HRFS30D4  \
# 0         1         1        -1  ...         1         1         0        -6
# 1         1         1        -1  ...         1         1         0        -6
# 2         1         1        -1  ...         1         1         0        -6
# 3         1         1        -1  ...         1         1         0        -6
# 4         1         1        -1  ...         1         1         0        -6
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138964 entries, 0 to 138963
# Columns: 510 entries, HRHHID to HRFS30DE
# dtypes: float64(1), int64(509)
# memory usage: 540.7 MB

# %%
data.select_dtypes(include=['float64'])
# Out:
#         FILLER
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 138959     NaN
# 138960     NaN
# 138961     NaN
# 138962     NaN
# 138963     NaN
#
# [138964 rows x 1 columns]

# %%
data['FILLER'].unique()
# Out:
# array([nan])

# %%
data.drop('FILLER', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138964 entries, 0 to 138963
# Columns: 509 entries, HRHHID to HRFS30DE
# dtypes: int64(509)
# memory usage: 539.6 MB

# %%
data.describe()
# Out:
#              HRHHID   HRMONTH   HRYEAR4       HURESPLI        HUFINAL  \
# count  1.389640e+05  138964.0  138964.0  138964.000000  138964.000000
# mean   3.515847e+14      12.0    2019.0       1.003994     189.968085
# std    2.926092e+14       0.0       0.0       0.964884      53.092961
# min    4.792610e+09      12.0    2019.0      -1.000000       1.000000
# 25%    1.053124e+14      12.0    2019.0       1.000000     201.000000
# 50%    2.660010e+14      12.0    2019.0       1.000000     201.000000
# 75%    6.005097e+14      12.0    2019.0       1.000000     201.000000
# max    9.997434e+14      12.0    2019.0      10.000000     259.000000
#
#           HULANGCODE       HETENURE       HEHOUSUT       HETELHHD  \
# count  138964.000000  138964.000000  138964.000000  138964.000000
# mean        0.036448       1.027338       1.252958       0.763428
# std         0.187403       0.884544       1.113010       0.713954
# min         0.000000      -1.000000       1.000000      -3.000000
# ...

# %%
data['HRYEAR4'].unique()
# Out:
# array([2019])

# %%
drop_list = ['FILLER', 'HRMONTH', 'HRYEAR4']

# %%
data.iloc[:,[30,32]]
# Out:
#         HUBUSL4  GEDIV
# 0            -1      9
# 1            -1      9
# 2            -1      9
# 3            -1      9
# 4            -1      7
# ...         ...    ...
# 138959       -1      8
# 138960       -1      8
# 138961       -1      8
# 138962       -1      8
# 138963       -1      8
#
# [138964 rows x 2 columns]
